# %% [markdown]
# 1. question  What is data cleaning, and why is it important in data analysis?
#  What are the potential consequences of analyzing unclean or messy data?
#  Explain the common steps involved in cleaning and organizing data?
#
#  - data cleaning maintain a  raw data in a manner way so that any person can read it without having promblem .
#
# - without cleaning data it can lead to   misinformation and misunderstanding  of data
#
#  - first step load data your unclean data and if there any lot of spaces use trim function
#  - second step use upper or lower for name
#  - use concat if there name and surname are in different cell

# %% [markdown]
# 2. question How would you sort the following dataset first by "Department" (A-Z) and then by "Salary" (Largest to
# Smallest)? Write a step-by-step approach
#
# ![Screenshot 2025-11-09 111815.png](data:image/png;base64,...)
#
# - answer 2.
# department
#
# - first we select the  all the data in table
#
# - and go to the data tab there is a option sort icon
# - click on it in column select department  and in order a to z sorting
# - click ok now it on a a to z format
# - and make sure header is on
#
# salary sorting.
#
# - for salary select all data in table
# - and again go  to the data tab
# - and add second level
# - and select salary in column
# - in order largest to small
# - and your department and salary all sort in a  manner way.
#
# here answer how it look
# ![Screenshot 2025-11-09 115020.png](data:image/png;base64,...)

# %% [markdown]
# 3. question Explain the use of text functions such as TRIM , LEFT, RIGHT, MID, and CONCAT in data cleaning?
#
#
# - answer3
# - trim :  if there is a any extra space between text it will remove the extra space to look data in a clean way
#  - example
#
#
#  ![Screenshot 2025-11-09 120019.png](data:image/png;base64,...)
#  - left : left function extract a specific number of a character from a left side  beginning text.
#
#  - example
#
#
#  ![Screenshot 2025-11-09 120820.png](data:image/png;base64,...)
#
#  - right :    it good for the extract last digit number like mobile number or adhar card number  it will extract the specific  number of a character  of  the right side last  text .
#
#  - example
#
#  ![Screenshot 2025-11-09 121513.png](data:image/png;base64,...)
#
#  - mid :   mid function help to extract specific number of character from the middle of a text .
#
#  - example
#
# ![Screenshot 2025-11-09 121958.png](data:image/png;base64,...)
#
#
# - concat ;  using for combine multiple string text it will automatically convert data into string .
#
# - example
#
# ![Screenshot 2025-11-09 122440.png](data:image/png;base64,...)

# %% [markdown]
# 4. question  What is the role of date functions like TODAY in managing datasets?
#
# - today is date function which is use for to get current date
#
# - it will show current date in data even you use date function tommorow or yeterday it will automatically replace the old  date with current date
#
# - in managing dataset it was  best for analyzing real time based data like share markter or renewal expire which cause less human error in dATA in calculation
# - and help in automation .

# %% [markdown]
# 5. question.  Apply Data Validation to restrict Quantity values to only whole numbers between 1 and 10.?
#
# 5.1  Configure an input message that appears when a user selects a cell in the "Quantity" column explaining:
#  "Please enter a whole number between 1 and 10."
#
# - ![Screenshot 2025-11-09 125427.png](data:image/png;base64,...)
#
#
#
#
# - FIRST WE CREATE A TABLE
# - AND IN A TABLE WE SELECT QUANTITY COLUMN
# - AND WE GO TO THE DATA TAB AND SELECT DATA VALIDATION ICON
# - AFTER THAT CLICK ON DATA VALIDATION
# - IN SETTING WE ALLOW WHOLE NUMBER
# - DATA IS ALREADY ON BETWEEN IF NOT THEN SELECT
# - AND GIVE NUMBER BETWEEN 1 TO 10
# - AND THAT HOW YOU APPLY DATA VALIDATION ON QUANTITY COLUMN
#
#   Q 5.1 Configure an input message that appears when a user selects a cell in the "Quantity" column explaining:
#  "Please enter a whole number between 1 and 10."
#
# - IN DATA VALDATION RIGHT SIDE OF SETTING THERE IS A OPTIONN OF INPUT MESSAGE CLICK ON IT.
# - AND ENTER YOUR MESSAGE GIVE TITLE FIRST
# - AND ENTER MESSAGE LIKE PLEASE ENTER A WHOLE NUMBER BETWEEN 1 TO 10 .
# - AND CLICK OK IT WILL APPLY ALL QUANTITY COLUMN . WHEN  YOU CLICK ON QUANTITY CELL IT WILL SHOW THE MESSAGE.
#
#
# Q5.2  Set up an error alert message that triggers if the user enters a number less than 1 or greater than 10,
# showing:
#  "Invalid input! The quantity must be a whole number between 1 and 10.
#
#
#  - GO TO THE LAST OPTION RIGHT SIDE OF INPUT THERE IS A OPTION ERROR ALERT
#  - SLECT STYLE STOP
#  - TITLE ERROR ALERT
#  - ENTER ERROR ALERT  "Invalid input! The quantity must be a whole number between 1 and 10.
#  - AND IT WILL APPLY .

# %% [markdown]
# 8. Understanding TODAY() and NOW()?
# - What is the difference between TODAY() and NOW() in Excel? Provide an example of when you would use
#  each function.
#
# answer 8.A
# - today function use if you want   current date.
# - it will automatically change date each day.
# - example deadline
# - no time include.
# - syntax =today()
#
#  syntax =now()
# - if you want  time and date it will both.
# - also include minute , second , hours.
# - best for time tracking.
# - real time base.
#
# question8.B  If cell A1 contains the date 2025-06-10, write a formula using TODAY() to determine how many days are
#  left until that date?
#  - =date(2025,06,10)- today() = -152
#
#  question 8.C  Write an Excel formula using NOW() to display the current date and time in the format MM/DD/YYYY
#  HH:MM AM/PM. ́
# -  =TEXT(NOW(), "mm/dd/yy, hh:mm: am/pm")
#
# question 8.D If a cell contains =TODAY(), what will happen when the worksheet is reopened the next day? Explain?
#
# - if cell contains =today() function in current day it will show  the current date only . but when we open next day it will automatically show  the new current date not the old one .
#
#
# question 8.E You want to store a static date (today’s date) in a cell without it changing every day. What keyboard
#  shortcut should you use?
#
#  - USE CTRL+ ;
